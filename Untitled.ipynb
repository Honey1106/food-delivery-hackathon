# %%
import pandas as pd

orders = pd.read_csv("orders.csv")

print(orders.head())
# Out:
#    order_id  user_id  restaurant_id  order_date  total_amount  \
# 0         1     2508            450  18-02-2023        842.97
# 1         2     2693            309  18-01-2023        546.68
# 2         3     2084            107  15-07-2023        163.93
# 3         4      319            224  04-10-2023       1155.97
# 4         5     1064            293  25-12-2023       1321.91
#
#                   restaurant_name
# 0               New Foods Chinese
# 1  Ruchi Curry House Multicuisine
# 2           Spice Kitchen Punjabi
# 3          Darbar Kitchen Non-Veg
# 4       Royal Eatery South Indian

# %%
users = pd.read_json("users.json")

print(users.head())
# Out:
#    user_id    name       city membership
# 0        1  User_1    Chennai    Regular
# 1        2  User_2       Pune       Gold
# 2        3  User_3  Bangalore       Gold
# 3        4  User_4  Bangalore    Regular
# 4        5  User_5       Pune       Gold

# %%
import sqlite3

# %%
conn = sqlite3.connect("restaurants.db")

# %%
with open("restaurants.sql", "r") as file:
    sql_script = file.read()

conn.executescript(sql_script)

# %%
restaurants = pd.read_sql("SELECT * FROM restaurants", conn)

print(restaurants.head())
# Out:
#    restaurant_id restaurant_name  cuisine  rating
# 0              1    Restaurant_1  Chinese     4.8
# 1              2    Restaurant_2   Indian     4.1
# 2              3    Restaurant_3  Mexican     4.3
# 3              4    Restaurant_4  Chinese     4.1
# 4              5    Restaurant_5  Chinese     4.8

# %%
orders_users = orders.merge(
    users,
    on="user_id",
    how="left"
)

# %%
final_df = orders_users.merge(
    restaurants,
    on="restaurant_id",
    how="left"
)

# %%
final_df.to_csv("final_food_delivery_dataset.csv", index=False)

# %%
final_df.head()
final_df.shape
final_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           10000 non-null  int64
#  1   user_id            10000 non-null  int64
#  2   restaurant_id      10000 non-null  int64
#  3   order_date         10000 non-null  str
#  4   total_amount       10000 non-null  float64
#  5   restaurant_name_x  10000 non-null  str
#  6   name               10000 non-null  str
#  7   city               10000 non-null  str
#  8   membership         10000 non-null  str
#  9   restaurant_name_y  10000 non-null  str
#  10  cuisine            10000 non-null  str
#  11  rating             10000 non-null  float64
# dtypes: float64(2), int64(3), str(7)
# memory usage: 937.6 KB

# %%
final_df.groupby("order_date").size()
# Out:
# order_date
# 01-01-2023    29
# 01-01-2024    27
# 01-02-2023    25
# 01-03-2023    37
# 01-04-2023    32
#               ..
# 31-05-2023    33
# 31-07-2023    27
# 31-08-2023    24
# 31-10-2023    30
# 31-12-2023    29
# Length: 366, dtype: int64

# %%
final_df.groupby("membership")["order_amount"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 final_df.groupby("membership")["order_amount"].sum()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:228, in SelectionMixin.__getitem__(self, key)
#     226 else:
#     227     if key not in self.obj:
# ...

# %%
final_df.groupby("city")["order_amount"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 final_df.groupby("city")["order_amount"].sum()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:228, in SelectionMixin.__getitem__(self, key)
#     226 else:
#     227     if key not in self.obj:
# ...

# %%
final_df.columns
# Out:
# Index(['order_id', 'user_id', 'restaurant_id', 'order_date', 'total_amount',
#        'restaurant_name_x', 'name', 'city', 'membership', 'restaurant_name_y',
#        'cuisine', 'rating'],
#       dtype='str')

# %%
final_df.groupby("membership")["amount"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 final_df.groupby("membership")["amount"].sum()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:228, in SelectionMixin.__getitem__(self, key)
#     226 else:
#     227     if key not in self.obj:
# ...

# %%
final_df.groupby("membership")["order amount"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 final_df.groupby("membership")["order amount"].sum()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:228, in SelectionMixin.__getitem__(self, key)
#     226 else:
#     227     if key not in self.obj:
# ...

# %%
final_df.columns = final_df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
final_df.groupby("membership")["order_amount"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 final_df.groupby("membership")["order_amount"].sum()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:228, in SelectionMixin.__getitem__(self, key)
#     226 else:
#     227     if key not in self.obj:
# ...

# %%
final_df.head()
# Out:
#    order_id  user_id  restaurant_id  order_date  total_amount  \
# 0         1     2508            450  18-02-2023        842.97
# 1         2     2693            309  18-01-2023        546.68
# 2         3     2084            107  15-07-2023        163.93
# 3         4      319            224  04-10-2023       1155.97
# 4         5     1064            293  25-12-2023       1321.91
#
#                 restaurant_name_x       name       city membership  \
# 0               New Foods Chinese  User_2508  Hyderabad    Regular
# 1  Ruchi Curry House Multicuisine  User_2693       Pune    Regular
# 2           Spice Kitchen Punjabi  User_2084    Chennai       Gold
# 3          Darbar Kitchen Non-Veg   User_319  Bangalore       Gold
# 4       Royal Eatery South Indian  User_1064       Pune    Regular
#
#   restaurant_name_y  cuisine  rating
# 0    Restaurant_450  Mexican     3.2
# 1    Restaurant_309   Indian     4.5
# 2    Restaurant_107  Mexican     4.0
# ...

# %%
final_df.columns
# Out:
# Index(['order_id', 'user_id', 'restaurant_id', 'order_date', 'total_amount',
#        'restaurant_name_x', 'name', 'city', 'membership', 'restaurant_name_y',
#        'cuisine', 'rating'],
#       dtype='str')

# %%
list(final_df.columns)
# Out:
# ['order_id',
#  'user_id',
#  'restaurant_id',
#  'order_date',
#  'total_amount',
#  'restaurant_name_x',
#  'name',
#  'city',
#  'membership',
#  'restaurant_name_y',
#  'cuisine',
#  'rating']

# %%
final_df.columns = (
    final_df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)

# %%
list(final_df.columns)
# Out:
# ['order_id',
#  'user_id',
#  'restaurant_id',
#  'order_date',
#  'total_amount',
#  'restaurant_name_x',
#  'name',
#  'city',
#  'membership',
#  'restaurant_name_y',
#  'cuisine',
#  'rating']

# %%
final_df.groupby("membership")["total_amount"].sum()
# Out:
# membership
# Gold       3975364.89
# Regular    4036259.23
# Name: total_amount, dtype: float64

# %%
list(final_df.columns)
# Out:
# ['order_id',
#  'user_id',
#  'restaurant_id',
#  'order_date',
#  'total_amount',
#  'restaurant_name_x',
#  'name',
#  'city',
#  'membership',
#  'restaurant_name_y',
#  'cuisine',
#  'rating']

# %%
# clean column names
final_df.columns = final_df.columns.str.strip().str.lower().str.replace(" ", "_")

# check missing values
final_df.isnull().sum()
# Out:
# order_id             0
# user_id              0
# restaurant_id        0
# order_date           0
# total_amount         0
# restaurant_name_x    0
# name                 0
# city                 0
# membership           0
# restaurant_name_y    0
# cuisine              0
# rating               0
# dtype: int64

# %%
final_df.head()
final_df.info()
final_df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           10000 non-null  int64
#  1   user_id            10000 non-null  int64
#  2   restaurant_id      10000 non-null  int64
#  3   order_date         10000 non-null  str
#  4   total_amount       10000 non-null  float64
#  5   restaurant_name_x  10000 non-null  str
#  6   name               10000 non-null  str
#  7   city               10000 non-null  str
#  8   membership         10000 non-null  str
#  9   restaurant_name_y  10000 non-null  str
#  10  cuisine            10000 non-null  str
#  11  rating             10000 non-null  float64
# dtypes: float64(2), int64(3), str(7)
# memory usage: 937.6 KB
#           order_id       user_id  restaurant_id  total_amount        rating
# count  10000.00000  10000.000000   10000.000000  10000.000000  10000.000000
# ...

# %%
final_df.groupby("order_date").size()
# Out:
# order_date
# 01-01-2023    29
# 01-01-2024    27
# 01-02-2023    25
# 01-03-2023    37
# 01-04-2023    32
#               ..
# 31-05-2023    33
# 31-07-2023    27
# 31-08-2023    24
# 31-10-2023    30
# 31-12-2023    29
# Length: 366, dtype: int64

# %%
final_df.groupby("order_date")["total_amount"].sum()
# Out:
# order_date
# 01-01-2023    25483.04
# 01-01-2024    17201.50
# 01-02-2023    21066.21
# 01-03-2023    32608.53
# 01-04-2023    26036.89
#                 ...
# 31-05-2023    23824.71
# 31-07-2023    23816.09
# 31-08-2023    18901.45
# 31-10-2023    22383.13
# 31-12-2023    19813.33
# Name: total_amount, Length: 366, dtype: float64

# %%
final_df.groupby("membership").size()
# Out:
# membership
# Gold       4987
# Regular    5013
# dtype: int64

# %%
final_df.groupby("membership")["total_amount"].sum()
# Out:
# membership
# Gold       3975364.89
# Regular    4036259.23
# Name: total_amount, dtype: float64

# %%
final_df.groupby("city")["total_amount"].sum().sort_values(ascending=False)
# Out:
# city
# Bangalore    2206946.58
# Chennai      1990513.03
# Pune         1924797.93
# Hyderabad    1889366.58
# Name: total_amount, dtype: float64

# %%
final_df.groupby("cuisine_type")["total_amount"].sum().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 final_df.groupby("cuisine_type")["total_amount"].sum().sort_values(ascending=False)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
# ...

# %%
final_df.groupby("restaurant_name")["total_amount"].sum().sort_values(ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 final_df.groupby("restaurant_name")["total_amount"].sum().sort_values(ascending=False).head(10)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
# ...

# %%
final_df["order_date"] = pd.to_datetime(final_df["order_date"])
# Out:
# C:\Users\hanis\AppData\Local\Temp\ipykernel_11396\206211785.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   final_df["order_date"] = pd.to_datetime(final_df["order_date"])

# %%
final_df.groupby("restaurant_name")["total_amount"].sum().sort_values(ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 final_df.groupby("restaurant_name")["total_amount"].sum().sort_values(ascending=False).head(10)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
# ...

# %%
final_df.to_csv("final_food_delivery_dataset.csv", index=False)

# %%
import pandas as pd

final_df = pd.read_csv("final_food_delivery_dataset.csv")
final_df.head()
# Out:
#    order_id  user_id  restaurant_id  order_date  total_amount  \
# 0         1     2508            450  2023-02-18        842.97
# 1         2     2693            309  2023-01-18        546.68
# 2         3     2084            107  2023-07-15        163.93
# 3         4      319            224  2023-10-04       1155.97
# 4         5     1064            293  2023-12-25       1321.91
#
#                 restaurant_name_x       name       city membership  \
# 0               New Foods Chinese  User_2508  Hyderabad    Regular
# 1  Ruchi Curry House Multicuisine  User_2693       Pune    Regular
# 2           Spice Kitchen Punjabi  User_2084    Chennai       Gold
# 3          Darbar Kitchen Non-Veg   User_319  Bangalore       Gold
# 4       Royal Eatery South Indian  User_1064       Pune    Regular
#
#   restaurant_name_y  cuisine  rating
# 0    Restaurant_450  Mexican     3.2
# 1    Restaurant_309   Indian     4.5
# 2    Restaurant_107  Mexican     4.0
# ...

# %%
final_df = pd.read_csv("final_food_delivery_dataset.csv")
final_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           10000 non-null  int64
#  1   user_id            10000 non-null  int64
#  2   restaurant_id      10000 non-null  int64
#  3   order_date         10000 non-null  str
#  4   total_amount       10000 non-null  float64
#  5   restaurant_name_x  10000 non-null  str
#  6   name               10000 non-null  str
#  7   city               10000 non-null  str
#  8   membership         10000 non-null  str
#  9   restaurant_name_y  10000 non-null  str
#  10  cuisine            10000 non-null  str
#  11  rating             10000 non-null  float64
# dtypes: float64(2), int64(3), str(7)
# memory usage: 937.6 KB

# %%
final_df = pd.read_csv("final_food_delivery_dataset.csv")

# %%
final_df.head()
final_df.shape
final_df.columns
final_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           10000 non-null  int64
#  1   user_id            10000 non-null  int64
#  2   restaurant_id      10000 non-null  int64
#  3   order_date         10000 non-null  str
#  4   total_amount       10000 non-null  float64
#  5   restaurant_name_x  10000 non-null  str
#  6   name               10000 non-null  str
#  7   city               10000 non-null  str
#  8   membership         10000 non-null  str
#  9   restaurant_name_y  10000 non-null  str
#  10  cuisine            10000 non-null  str
#  11  rating             10000 non-null  float64
# dtypes: float64(2), int64(3), str(7)
# memory usage: 937.6 KB

# %%
final_df.columns = final_df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
total_orders = final_df.shape[0]
total_revenue = final_df["total_amount"].sum()

total_orders, total_revenue
# Out:
# (10000, np.float64(8011624.12))

# %%
final_df["order_date"] = pd.to_datetime(final_df["order_date"])

orders_by_day = final_df.groupby("order_date").size()

# %%
final_df.groupby("membership")["total_amount"].agg(["count", "sum", "mean"])
# Out:
#             count         sum        mean
# membership
# Gold         4987  3975364.89  797.145556
# Regular      5013  4036259.23  805.158434

# %%
final_df.groupby("city")["total_amount"].sum().sort_values(ascending=False)
# Out:
# city
# Bangalore    2206946.58
# Chennai      1990513.03
# Pune         1924797.93
# Hyderabad    1889366.58
# Name: total_amount, dtype: float64

# %%
final_df.groupby("cuisine_type")["total_amount"].sum().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 final_df.groupby("cuisine_type")["total_amount"].sum().sort_values(ascending=False)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
# ...

# %%
list(final_df.columns)
# Out:
# ['order_id',
#  'user_id',
#  'restaurant_id',
#  'order_date',
#  'total_amount',
#  'restaurant_name_x',
#  'name',
#  'city',
#  'membership',
#  'restaurant_name_y',
#  'cuisine',
#  'rating']

# %%
final_df.columns = final_df.columns.str.strip().str.lower().str.replace(" ", "_")
list(final_df.columns)
# Out:
# ['order_id',
#  'user_id',
#  'restaurant_id',
#  'order_date',
#  'total_amount',
#  'restaurant_name_x',
#  'name',
#  'city',
#  'membership',
#  'restaurant_name_y',
#  'cuisine',
#  'rating']

# %%
final_df.groupby("cuisine")["total_amount"].sum().sort_values(ascending=False)
# Out:
# cuisine
# Mexican    2085503.09
# Italian    2024203.80
# Indian     1971412.58
# Chinese    1930504.65
# Name: total_amount, dtype: float64

# %%
final_df.groupby("restaurant_cuisine")["total_amount"].sum().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 final_df.groupby("restaurant_cuisine")["total_amount"].sum().sort_values(ascending=False)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
# ...

# %%
[col for col in final_df.columns if "cuisine" in col or "food" in col]
# Out:
# ['cuisine']
